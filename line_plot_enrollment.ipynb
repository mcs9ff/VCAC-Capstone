# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cleaned_combined_2015_2020.csv')

# %%
df.head()
# Out:
#    student_totals_seniors  specific_interactions_1-on-1s_total  \
# 0                   148.0                                724.0
# 1                   247.0                                837.0
# 2                   136.0                               1679.0
# 3                   676.0                                298.0
# 4                    96.0                                488.0
#
#    specific_interactions_group_total  \
# 0                              644.0
# 1                              726.0
# 2                              799.0
# 3                              150.0
# 4                              158.0
#
#    specific_interactions_1-on-1s_at_least_one  \
# 0                                       126.0
# 1                                       234.0
# 2                                       128.0
# 3                                       142.0
# 4                                        81.0
#
#    specific_interactions_group_at_least_one  \
# ...

# %%
schools_grouped = df.groupby('school_name')

plt.figure(figsize=(22, 6)) 
for name, group in schools_grouped:
    plt.plot(group['year_starting'], group['enrolled_rate'], label=name)

plt.xlabel('Year')
plt.ylabel('Enrollment Rate')
plt.title('Enrollment Rates Over Years')
#plt.legend()
plt.grid(True)
plt.show()
