# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
# Out:
# /var/folders/zx/rrsnqrlj32d4zdyzdhfp0xhh0000gn/T/ipykernel_7287/3554415.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('cleaned_combined_2015_2020.csv')
df.head()
# Out:
#    student_totals_seniors  specific_interactions_1-on-1s_total  \
# 0                   137.0                               1073.0
# 1                   263.0                                801.0
# 2                   122.0                                501.0
# 3                   153.0                                192.0
# 4                   267.0                               1606.0
#
#    specific_interactions_group_total  \
# 0                              438.0
# 1                              638.0
# 2                              215.0
# 3                              373.0
# 4                             1196.0
#
#    specific_interactions_1-on-1s_at_least_one  \
# 0                                       123.0
# 1                                       261.0
# 2                                       112.0
# 3                                       122.0
# 4                                       267.0
#
#    specific_interactions_group_at_least_one  \
# 0                                     116.0
# 1                                     246.0
# 2                                      86.0
# 3                                     134.0
# 4                                     253.0
#
#    specific_interactions_parent_meetings  \
# 0                                   33.0
# 1                                  262.0
# 2                                   48.0
# 3                                   16.0
# 4                                  163.0
#
#    specific_interactions_parent_meetings_at_least_one  \
# 0                                               25.0
# 1                                              136.0
# 2                                               35.0
# 3                                               14.0
# 4                                               91.0
#
#    total_interactions_met_with_1_plus_times_(group_and_1_1)  \
# 0                                              131.0
# 1                                              261.0
# 2                                              113.0
# 3                                              142.0
# 4                                              267.0
#
#    total_interactions_met_with_3_plus_times_(group_and_1_1)  \
# 0                                              115.0
# 1                                              233.0
# 2                                               89.0
# 3                                              111.0
# 4                                              250.0
#
#    total_interactions_met_with_5_plus_times_(group_and_1_1)  ...  \
# 0                                               90.0         ...
# 1                                              161.0         ...
# 2                                               57.0         ...
# 3                                               38.0         ...
# 4                                              210.0         ...
#
#    college_waivers_students_w_1_plus_rate  \
# 0                                0.408759
# 1                                0.193916
# 2                                0.098361
# 3                                0.013072
# 4                                0.029963
#
#    college_waivers_total_#_waivers_rate  \
# 0                              1.270073
# 1                              0.323194
# 2                              0.188525
# 3                              0.019608
# 4                              0.149813
#
#    college_waivers_total_waiver_dollars_rate  \
# 0                                  64.963504
# 1                                  16.844106
# 2                                  12.254098
# 3                                   1.176471
# 4                                   9.644195
#
#    institutional_aid_students_w_1_plus_rate  \
# 0                                  0.138686
# 1                                  0.121673
# 2                                  0.237705
# 3                                  0.183007
# 4                                  0.089888
#
#    institutional_aid_total_dollars_rate  \
# 0                          12318.569343
# 1                           8608.520913
# 2                           4872.680328
# 3                           9011.973856
# 4                           3377.393258
#
#    institutional_aid_students_w_1_plus_award_letter_reviews_rate  \
# 0                                           0.065693
# 1                                           0.022814
# 2                                           0.081967
# 3                                           0.045752
# 4                                           0.191011
#
#    institutional_aid_total_award_letter_meetings_rate  fafsa_submitted_rate  \
# 0                                           0.080292               0.496350
# 1                                           0.022814               0.612167
# 2                                           0.114754               0.319672
# 3                                           0.045752               0.529412
# 4                                           0.284644               0.591760
#
#    scholarships_students_w_1_plus_rate  scholarships_total_dollars_rate
# 0                             0.102190                       288.321168
# 1                             0.220532                      6293.212928
# 2                             0.262295                       674.385246
# 3                             0.189542                       630.294118
# 4                             0.172285                      1623.164794
#
# [5 rows x 93 columns]

# %%
column_names = df.columns
column_names_df = pd.DataFrame({'features':column_names})
display(column_names_df)
# Out:
#                                              features
# 0                              student_totals_seniors
# 1                 specific_interactions_1-on-1s_total
# 2                   specific_interactions_group_total
# 3          specific_interactions_1-on-1s_at_least_one
# 4            specific_interactions_group_at_least_one
# 5               specific_interactions_parent_meetings
# 6   specific_interactions_parent_meetings_at_least...
# 7   total_interactions_met_with_1_plus_times_(grou...
# 8   total_interactions_met_with_3_plus_times_(grou...
# 9   total_interactions_met_with_5_plus_times_(grou...
# 10  total_interactions_met_with_10_plus_times_(gro...
# 11                    college_awareness_campus_visits
# 12       college_awareness_campus_visits_at_least_one
# 13                     college_awareness_college_fair
# 14       college_awareness_college_fairs_at_least_one
# 15               college_awareness_college_rep_visits
# 16  college_awareness_college_rep_visits_at_least_one
# 17                                 act_sats_completed
# 18                 act_sats_registered_for_sat_or_act
# 19                        act_sats_registered_for_sat
# 20                        act_sats_registered_for_act
# 21     act_sats_assisted_registration_with_sat_or_act
# 22            act_sats_assisted_registration_with_sat
# 23            act_sats_assisted_registration_with_act
# 24                                    act_sats_waiver
# 25                           act_sats_assisted_waiver
# 26                     act_sats_sat_act_prep_meetings
# 27        act_sats_sat_act_prep_meetings_at_least_one
# 28                 college_apps_submitted_1_plus_apps
# 29                 college_apps_submitted_3_plus_apps
# 30                 college_apps_submitted_5_plus_apps
# 31           college_apps_submitted_total_#_submitted
# 32                  college_apps_accepted_1_plus_apps
# 33                  college_apps_accepted_3_plus_apps
# 34                  college_apps_accepted_5_plus_apps
# 35             college_apps_accepted_total_#_accepted
# 36                  college_waivers_students_w_1_plus
# 37                    college_waivers_total_#_waivers
# 38               college_waivers_total_waiver_dollars
# 39                institutional_aid_students_w_1_plus
# 40                    institutional_aid_total_dollars
# 41  institutional_aid_students_w_1_plus_award_lett...
# 42      institutional_aid_total_award_letter_meetings
# 43                                    fafsa_submitted
# 44                     scholarships_students_w_1_plus
# 45                         scholarships_total_dollars
# 46                                      year_starting
# 47                                        school_name
# 48           specific_interactions_1-on-1s_total_rate
# 49             specific_interactions_group_total_rate
# 50    specific_interactions_1-on-1s_at_least_one_rate
# 51      specific_interactions_group_at_least_one_rate
# 52         specific_interactions_parent_meetings_rate
# 53  specific_interactions_parent_meetings_at_least...
# 54  total_interactions_met_with_1_plus_times_(grou...
# 55  total_interactions_met_with_3_plus_times_(grou...
# 56  total_interactions_met_with_5_plus_times_(grou...
# 57  total_interactions_met_with_10_plus_times_(gro...
# 58               college_awareness_campus_visits_rate
# 59  college_awareness_campus_visits_at_least_one_rate
# 60                college_awareness_college_fair_rate
# 61  college_awareness_college_fairs_at_least_one_rate
# 62          college_awareness_college_rep_visits_rate
# 63  college_awareness_college_rep_visits_at_least_...
# 64                            act_sats_completed_rate
# 65            act_sats_registered_for_sat_or_act_rate
# 66                   act_sats_registered_for_sat_rate
# 67                   act_sats_registered_for_act_rate
# 68  act_sats_assisted_registration_with_sat_or_act...
# 69       act_sats_assisted_registration_with_sat_rate
# 70       act_sats_assisted_registration_with_act_rate
# 71                               act_sats_waiver_rate
# 72                      act_sats_assisted_waiver_rate
# 73                act_sats_sat_act_prep_meetings_rate
# 74   act_sats_sat_act_prep_meetings_at_least_one_rate
# 75            college_apps_submitted_1_plus_apps_rate
# 76            college_apps_submitted_3_plus_apps_rate
# 77            college_apps_submitted_5_plus_apps_rate
# 78      college_apps_submitted_total_#_submitted_rate
# 79             college_apps_accepted_1_plus_apps_rate
# 80             college_apps_accepted_3_plus_apps_rate
# 81             college_apps_accepted_5_plus_apps_rate
# 82        college_apps_accepted_total_#_accepted_rate
# 83             college_waivers_students_w_1_plus_rate
# 84               college_waivers_total_#_waivers_rate
# 85          college_waivers_total_waiver_dollars_rate
# 86           institutional_aid_students_w_1_plus_rate
# 87               institutional_aid_total_dollars_rate
# 88  institutional_aid_students_w_1_plus_award_lett...
# 89  institutional_aid_total_award_letter_meetings_...
# 90                               fafsa_submitted_rate
# 91                scholarships_students_w_1_plus_rate
# 92                    scholarships_total_dollars_rate

# %%
def corr_func(x, y, **kwargs):
    r = np.corrcoef(x, y)[0][1]
    ax = plt.gca()
    ax.annotate(f'Corr: {r:.2f}', xy=(.1, .9), xycoords=ax.transAxes)

def create_pairs_plot(df, variables):
    """
    Create a pairs plot of the given variables.
    
    Args:
    df: DataFrame
    variables: list of variable names to include in the plot from the DataFrame
    """
    g = sns.PairGrid(df[variables])
    g.map_lower(sns.scatterplot)
    g.map_upper(corr_func)
    g.map_diag(sns.histplot)
    plt.show()

# %%
def plot_scatter(df, x_var, y_var):
    # generate a docstring
    """
    Create a scatter plot with a regression line and highlights outliers.
    
    Args:
    df: The input dataframe that contains the data
    x_var: The name of the x variable
    y_var: The name of the y variable
    return: A scatter plot with a regression line and highlighted outliers
    """
    
    # Calculate Z-scores
    df['Z_x'] = np.abs(zscore(df[x_var]))
    df['Z_y'] = np.abs(zscore(df[y_var]))

    # Create a scatter plot with a regression line
    sns.regplot(x=x_var, y=y_var, data=df, color='blue', line_kws={'color': 'black'})

    # Highlight outliers
    outliers = df[(df['Z_x'] > 3) | (df['Z_y'] > 3)]
    plt.scatter(outliers[x_var], outliers[y_var], color='red', label='Outliers')
    plt.xlabel(x_var)
    plt.ylabel(y_var)
    plt.title(f'{y_var} vs {x_var}')
    plt.show()

    # Print the correlation
    print("Correlation: ", df[x_var].corr(df[y_var]))

# %%
def create_boxplot(df, x_var, y_var):
    """Create a boxplot of y_var by x_var.

    Args:
    df (DataFrame): The input DataFrame
    x_var (str): The column name of the x variable
    y_var (str): The column name of the y variable
    """
    sns.boxplot(x=x_var, y=y_var, data=df, palette='Set1')
    plt.title(f'{y_var} by {x_var}')
    plt.xlabel(x_var)
    plt.ylabel(y_var)
    plt.xticks(rotation=45)
    plt.show()
